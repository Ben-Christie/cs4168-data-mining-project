# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold 
from sklearn import cluster 
from sklearn import preprocessing

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv("./prepared_mushrooms_sample.csv")

df.head(1)
# Out:
#    Unnamed: 0  ring-number  bruises_true  cap-color_buff  cap-color_cinammon  \
# 0           0            1             1               0                   0
#
#    cap-color_gray  cap-color_green  cap-color_pink  cap-color_purple  \
# 0               0                0               0                 0
#
#    cap-color_red  ...  stalk-shape_tapering  stalk-surface-above-ring_scaly  \
# 0              1  ...                     1                               0
#
#    stalk-surface-above-ring_silky  stalk-surface-above-ring_smooth  \
# 0                               0                                1
#
#    stalk-surface-below-ring_scaly  stalk-surface-below-ring_silky  \
# 0                               0                               0
#
#    stalk-surface-below-ring_smooth  veil-color_orange  veil-color_white  \
# 0                                1                  0                 1
#
#    veil-color_yellow
# 0                  0
#
# [1 rows x 96 columns]

# %% [markdown]
# ##### Dropping irrelevant col

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head(1)
# Out:
#    ring-number  bruises_true  cap-color_buff  cap-color_cinammon  \
# 0            1             1               0                   0
#
#    cap-color_gray  cap-color_green  cap-color_pink  cap-color_purple  \
# 0               0                0               0                 0
#
#    cap-color_red  cap-color_white  ...  stalk-shape_tapering  \
# 0              1                0  ...                     1
#
#    stalk-surface-above-ring_scaly  stalk-surface-above-ring_silky  \
# 0                               0                               0
#
#    stalk-surface-above-ring_smooth  stalk-surface-below-ring_scaly  \
# 0                                1                               0
#
#    stalk-surface-below-ring_silky  stalk-surface-below-ring_smooth  \
# 0                               0                                1
#
#    veil-color_orange  veil-color_white  veil-color_yellow
# 0                  0                 1                  0
#
# [1 rows x 95 columns]

# %%
data = np.array(df.values, dtype=float)
print('(number of examples, number of attributes): ', data.shape)
# Out:
# (number of examples, number of attributes):  (4000, 95)

# %% [markdown]
# ## Rescale Data

# %% [markdown]
# #### Other than ring-number all data is either 0 or 1 (was orginally categorical),
# ##### can convert ring-number into an interval between [0,1] using MinMaxScaler

# %%
min_max_scaler = preprocessing.MinMaxScaler()
data = min_max_scaler.fit_transform(data)

# %% [markdown]
# ##### Using code from lab 3 - can visualise the cluster

# %%
colors = np.array(['orange', 'blue', 'lime', 'blue', 'khaki', 'pink', 'green', 'purple'])

# points - a 2D array of (x,y) coordinates of data points
# labels - an array of numeric labels in the interval [0..k-1], one for each point
# centers - a 2D array of (x, y) coordinates of cluster centers
# title - title of the plot


def clustering_scatterplot(points, labels, centers, title):
    
    
    n_clusters = np.unique(labels).size
    for i in range(n_clusters):
        h = plt.scatter(points[labels==i,0],
                        points[labels==i,1], 
                        c=colors[i%colors.size],
                        label = 'cluster '+str(i))

    # plot the centers of the clusters
    if centers is not None:
        plt.scatter(centers[:,0], centers[:,1], c='r', marker='*', s=500)

    _ = plt.title(title)
    _ = plt.legend()
    _ = plt.xlabel('x')
    _ = plt.ylabel('y')

# %% [markdown]
# ## K Means clustering

# %% [markdown]
# #### K means clustering is an unsupervised machine learning algorithm, the goal of the algorithm is
# #### to find groups within the dataset, the algorithm works by assigning each data point to
# #### one of the k clusters

# %% [markdown]
# ##### Finding the optimal value for k using the Elbow technique

# %%
k_values = range(1, 11)

# Calculate SSD for each value of K
ssd = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    ssd.append(kmeans.inertia_)

# Plot the SSD values for each K
plt.plot(k_values, ssd, 'bx-')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Sum of squared distances (SSD)')
plt.title('Elbow Method for Optimal K')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [25], line 5
#       3 for num_clusters in K :
#       4      kmeans = cluster.KMeans(n_clusters=num_clusters)
# ----> 5      cluster.KMeans.fit(data)
#       6      Sum_of_squared_distances.append(kmeans.inertia_)
#       7 plt.plot(K,Sum_of_squared_distances,'bx-')
#
# TypeError: fit() missing 1 required positional argument: 'X'

# %%
k = 3

# %%
clustered_data_sklearn = cluster.KMeans(n_clusters=k, n_init=10, max_iter=50).fit(data)

# %% [markdown]
# ## Applying multi-dimensional scaling (MDS) to project the data and
# ## K means clusters to a 2D space

# %%
data_and_centers = np.r_[data,clustered_data_sklearn.cluster_centers_]

# %%
XYcoordinates = manifold.MDS(n_components=2).fit_transform(data_and_centers)
print("transformation complete")
# Out:
# C:\Users\aaron\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# transformation complete

# %%
clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_, 
                       centers=XYcoordinates[-k:,:], 
                       title='MDS')

# %% [markdown]
# ## Applying t-SNE to project the data and clusters to a 2D space

# %%
XYcoordinates = manifold.TSNE(n_components=2).fit_transform(data_and_centers)
print("transformation complete")
# Out:
# transformation complete

# %%
clustering_scatterplot(points=XYcoordinates[:-k,:], 
                       labels=clustered_data_sklearn.labels_,
                       centers=XYcoordinates[-k:,:], 
                       title='TSNE')

# %% [markdown]
# ### Adding the cluster labels to the original dataframe

# %%
df['cluster'] = pd.Series(clustered_data_sklearn.labels_, index=df.index)

# %% [markdown]
# #### mean value for each attribute for each cluster

# %%
pd.set_option('display.max_columns', None)
df.groupby('cluster').mean()
# Out:
#          ring-number  bruises_true  cap-color_buff  cap-color_cinammon  \
# cluster
# 0           1.120098      0.680556        0.035948            0.006127
# 1           0.997750      0.000000        0.000000            0.000000
# 2           0.978884      0.000000        0.000000            0.003017
#
#          cap-color_gray  cap-color_green  cap-color_pink  cap-color_purple  \
# cluster
# 0              0.237337         0.004085        0.033905          0.002859
# 1              0.000000         0.000000        0.000000          0.000000
# 2              0.506787         0.000000        0.000000          0.000000
#
#          cap-color_red  cap-color_white  cap-color_yellow  cap-shape_conical  \
# cluster
# 0             0.124592         0.204657          0.071895           0.000408
# 1             0.469066         0.000000          0.007874           0.000000
# 2             0.007541         0.000000          0.472097           0.000000
#
#          cap-shape_convex  cap-shape_flat  cap-shape_knobbed  \
# cluster
# 0                0.467320        0.391748           0.045752
# 1                0.320585        0.340832           0.332958
# 2                0.496229        0.499246           0.004525
#
#          cap-shape_sunken  cap-surface_grooves  cap-surface_scaly  \
# cluster
# 0                 0.00817             0.000817           0.335784
# 1                 0.00000             0.000000           0.508436
# 2                 0.00000             0.000000           0.521870
#
#          cap-surface_smooth  class_poisonous  gill-attachment_free  \
# cluster
# 0                  0.334967         0.183007              0.962827
# 1                  0.480315         1.000000              0.997750
# 2                  0.000000         1.000000              0.990950
#
#          gill-color_brown  gill-color_buff  gill-color_chocolate  \
# cluster
# 0                0.198121         0.000000              0.066176
# 1                0.000000         0.978628              0.000000
# 2                0.000000         0.000000              0.310709
#
#          gill-color_gray  gill-color_green  gill-color_orange  \
# cluster
# 0               0.064542          0.006536           0.013072
# 1               0.000000          0.000000           0.000000
# 2               0.334842          0.000000           0.000000
#
#          gill-color_pink  gill-color_purple  gill-color_red  gill-color_white  \
# cluster
# 0               0.203840            0.10049        0.022059          0.234069
# 1               0.000000            0.00000        0.000000          0.020247
# 2               0.333333            0.00000        0.000000          0.010558
#
#          gill-color_yellow  gill-size_narrow  gill-spacing_crowded  \
# cluster
# 0                 0.013072          0.158905              0.251634
# 1                 0.001125          0.997750              0.000000
# 2                 0.010558          0.000000              0.000000
#
#          habitat_leaves  habitat_meadows  habitat_paths  habitat_urban  \
# cluster
# 0              0.050654         0.060458       0.024918       0.080474
# 1              0.314961         0.000000       0.320585       0.000000
# 2              0.000000         0.000000       0.355958       0.000000
#
#          habitat_waste  habitat_woods  odor_anise  odor_creosote  odor_fishy  \
# cluster
# 0             0.040033       0.407680    0.077614        0.04085    0.000000
# 1             0.000000       0.364454    0.000000        0.00000    0.320585
# 2             0.000000       0.340875    0.000000        0.00000    0.000000
#
#          odor_foul  odor_musty  odor_none  odor_pungent  odor_spicy  \
# cluster
# 0         0.062500    0.000000   0.684232      0.058007     0.00000
# 1         0.334083    0.002250   0.019123      0.000000     0.32396
# 2         0.978884    0.021116   0.000000      0.000000     0.00000
#
#          population_clustered  population_numerous  population_scattered  \
# cluster
# 0                    0.061275              0.07884              0.246324
# 1                    0.002250              0.00000              0.000000
# 2                    0.021116              0.00000              0.000000
#
#          population_several  population_solitary  ring-type_flaring  \
# cluster
# 0                  0.334150             0.209559           0.008987
# 1                  0.997750             0.000000           0.000000
# 2                  0.487179             0.491704           0.000000
#
#          ring-type_large  ring-type_none  ring-type_pendant  \
# cluster
# 0               0.000000        0.000000           0.794935
# 1               0.000000        0.002250           0.000000
# 2               0.978884        0.021116           0.000000
#
#          spore-print-color_brown  spore-print-color_buff  \
# cluster
# 0                       0.379902                0.008987
# 1                       0.000000                0.000000
# 2                       0.000000                0.000000
#
#          spore-print-color_chocolate  spore-print-color_green  \
# cluster
# 0                           0.071487                 0.017974
# 1                           0.000000                 0.000000
# 2                           0.978884                 0.000000
#
#          spore-print-color_orange  spore-print-color_purple  \
# cluster
# 0                         0.00817                  0.009804
# 1                         0.00000                  0.000000
# 2                         0.00000                  0.000000
#
#          spore-print-color_white  spore-print-color_yellow  \
# cluster
# 0                       0.115605                  0.011029
# 1                       1.000000                  0.000000
# 2                       0.021116                  0.000000
#
#          stalk-color-above-ring_buff  stalk-color-above-ring_cinammon  \
# cluster
# 0                           0.000000                         0.000000
# 1                           0.000000                         0.002250
# 2                           0.330317                         0.021116
#
#          stalk-color-above-ring_gray  stalk-color-above-ring_orange  \
# cluster
# 0                           0.102533                       0.037173
# 1                           0.000000                       0.000000
# 2                           0.000000                       0.000000
#
#          stalk-color-above-ring_pink  stalk-color-above-ring_red  \
# cluster
# 0                           0.121732                    0.019199
# 1                           0.488189                    0.000000
# 2                           0.307692                    0.000000
#
#          stalk-color-above-ring_white  stalk-color-above-ring_yellow  \
# cluster
# 0                            0.715278                       0.002042
# 1                            0.509561                       0.000000
# 2                            0.000000                       0.000000
#
#          stalk-color-below-ring_buff  stalk-color-below-ring_cinammon  \
# cluster
# 0                           0.000000                         0.000000
# 1                           0.000000                         0.002250
# 2                           0.312217                         0.021116
#
#          stalk-color-below-ring_gray  stalk-color-below-ring_orange  \
# cluster
# 0                            0.10866                       0.037173
# 1                            0.00000                       0.000000
# 2                            0.00000                       0.000000
#
#          stalk-color-below-ring_pink  stalk-color-below-ring_red  \
# cluster
# 0                           0.116013                    0.021242
# 1                           0.491564                    0.000000
# 2                           0.333333                    0.000000
#
#          stalk-color-below-ring_white  stalk-color-below-ring_yellow  \
# cluster
# 0                            0.703023                       0.002042
# 1                            0.487064                       0.011249
# 2                            0.000000                       0.000000
#
#          stalk-root_club_1  stalk-root_equal_1  stalk-root_nan_1  \
# cluster
# 0                 0.102124            0.222631          0.140114
# 1                 0.002250            0.000000          0.997750
# 2                 0.021116            0.000000          0.000000
#
#          stalk-root_rooted_1  stalk-shape_tapering  \
# cluster
# 0                   0.037173              0.563725
# 1                   0.000000              0.978628
# 2                   0.000000              0.000000
#
#          stalk-surface-above-ring_scaly  stalk-surface-above-ring_silky  \
# cluster
# 0                              0.004085                        0.028186
# 1                              0.000000                        0.511811
# 2                              0.000000                        1.000000
#
#          stalk-surface-above-ring_smooth  stalk-surface-below-ring_scaly  \
# cluster
# 0                               0.861111                        0.041258
# 1                               0.488189                        0.021372
# 2                               0.000000                        0.021116
#
#          stalk-surface-below-ring_silky  stalk-surface-below-ring_smooth  \
# cluster
# 0                              0.026552                         0.818219
# 1                              0.478065                         0.500562
# 2                              0.978884                         0.000000
#
#          veil-color_orange  veil-color_white  veil-color_yellow
# cluster
# 0                 0.019199          0.960784           0.002042
# 1                 0.000000          1.000000           0.000000
# 2                 0.000000          1.000000           0.000000

# %%
## Looking at the clusters, cluster 1 and 3 are very obviously of class poisonous
